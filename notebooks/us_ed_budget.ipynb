# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests

# %%
doe_2022
# Out:
#                                              Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                               DEPARTMENT OF EDUCATION        NaN        NaN
# 1     Funds for State Formula-Allocated and Selected...        NaN        NaN
# 2                                                   NaN        NaN        NaN
# 3                                                 Index        NaN        NaN
# 4                                                   NaN        NaN        NaN
# ...                                                 ...        ...        ...
# 2589                                                NaN        NaN        NaN
# 2590                                                NaN        NaN        NaN
# 2591                                                NaN        NaN        NaN
# 2592                                                NaN        NaN        NaN
# 2593                                                NaN        NaN        NaN
#
# ...

# %%
doe_2022 = pd.read_csv('../data/doe_2022.csv', encoding="cp1252")

# %%
doe_2022=doe_2022.reset_index(drop=True)

# %%
doe_2022 = doe_2022.iloc[2177:2228, 0:2]

# %%
doe_2022.columns = ["State or Other Area", "2022"]

# %%
doe_2022["2022"] = doe_2022["2022"].str.replace(",", "").astype(int)

# %%
doe_2022.head()
# Out:
#      State or Other Area         2022
# 2177             Alabama   2533745786
# 2178              Alaska    377218230
# 2179             Arizona   5424202388
# 2180            Arkansas   1266409261
# 2181          California  16930897583

# %%
doe_2022.tail()
# Out:
#      State or Other Area        2022
# 2223            Virginia  4411761992
# 2224          Washington  2285866171
# 2225       West Virginia  1047911882
# 2226           Wisconsin  2195977973
# 2227             Wyoming   238693019

# %%
doe_2001_2008 = pd.read_csv('../data/doe_2001_2008.csv', encoding="cp1252")

# %%
doe_2001_2008=doe_2001_2008.reset_index(drop=True)

# %%
doe_2001_2008 = doe_2001_2008.iloc[4550:4601, 0:16]
doe_2001_2008
# Out:
#                 Unnamed: 0      Unnamed: 1  Unnamed: 2      Unnamed: 3  \
# 4550               Alabama  1,205,096,441          NaN  1,387,975,241
# 4551                Alaska    227,988,480          NaN    260,180,178
# 4552               Arizona  1,990,909,460          NaN  2,520,137,525
# 4553              Arkansas    618,218,324          NaN    733,650,835
# 4554            California  7,895,473,833          NaN  9,092,121,808
# 4555              Colorado  1,061,188,114          NaN  1,238,777,106
# 4556           Connecticut    703,315,579          NaN    825,970,250
# 4557              Delaware    187,754,734          NaN    216,149,404
# 4558  District of Columbia    596,359,049          NaN    663,632,391
# 4559               Florida  3,622,745,422          NaN  4,124,966,740
# 4560               Georgia  1,973,334,617          NaN  2,313,606,367
# 4561                Hawaii    229,367,192          NaN    271,216,945
# ...

# %%
doe_2001_2008.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14', 'Unnamed: 15'],
#       dtype='object')

# %%
doe_2001_2008 = doe_2001_2008.drop(columns=['Unnamed: 2', 'Unnamed: 4', 'Unnamed: 6', 'Unnamed: 8', 'Unnamed: 10','Unnamed: 12', 'Unnamed: 14'])

# %%
doe_2001_2008
# Out:
#                 Unnamed: 0      Unnamed: 1      Unnamed: 3      Unnamed: 5  \
# 4550               Alabama  1,205,096,441   1,387,975,241   1,584,581,070
# 4551                Alaska    227,988,480     260,180,178     280,079,667
# 4552               Arizona  1,990,909,460   2,520,137,525   3,103,945,066
# 4553              Arkansas    618,218,324     733,650,835     829,601,733
# 4554            California  7,895,473,833   9,092,121,808   9,928,105,199
# 4555              Colorado  1,061,188,114   1,238,777,106   1,416,997,560
# 4556           Connecticut    703,315,579     825,970,250     908,683,240
# 4557              Delaware    187,754,734     216,149,404     226,632,147
# 4558  District of Columbia    596,359,049     663,632,391     747,391,195
# 4559               Florida  3,622,745,422   4,124,966,740   4,631,097,940
# 4560               Georgia  1,973,334,617   2,313,606,367   2,618,655,949
# 4561                Hawaii    229,367,192     271,216,945     296,507,436
# ...

# %%
doe_2001_2008.columns = ["State or Other Area", "2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008"]

# %%
cols = ["2001", "2002", "2003", "2004", "2005", "2006", "2007", "2008"]
doe_2001_2008[cols] = doe_2001_2008[cols].replace({",": ""}, regex=True).astype(int)

# %%
doe_2001_2008
# Out:
#        State or Other Area        2001        2002        2003         2004  \
# 4550               Alabama  1205096441  1387975241  1584581070   1672101861
# 4551                Alaska   227988480   260180178   280079667    299103691
# 4552               Arizona  1990909460  2520137525  3103945066   4312713049
# 4553              Arkansas   618218324   733650835   829601733    888970231
# 4554            California  7895473833  9092121808  9928105199  10825485264
# 4555              Colorado  1061188114  1238777106  1416997560   1665593582
# 4556           Connecticut   703315579   825970250   908683240    965299387
# 4557              Delaware   187754734   216149404   226632147    286492122
# 4558  District of Columbia   596359049   663632391   747391195    832483943
# 4559               Florida  3622745422  4124966740  4631097940   5181788479
# 4560               Georgia  1973334617  2313606367  2618655949   3047639805
# ...

# %%
doe_2009 = pd.read_csv('../data/doe_2009.csv', encoding="cp1252") 
doe_2009 = doe_2009.reset_index(drop=True)

# %%
doe_2009 = doe_2009.iloc[4046:4097, 0:4]

# %%
doe_2009 = doe_2009.drop(columns=['Unnamed: 1', 'Unnamed: 2'])

# %%
doe_2009.columns = ["State or Other Area", "2009"]
doe_2009["2009"] = doe_2009["2009"].str.replace(",", "").astype(int)

# %%
doe_2009
# Out:
#        State or Other Area         2009
# 4046               Alabama   2472093599
# 4047                Alaska    347373460
# 4048               Arizona   8052788118
# 4049              Arkansas   1303196239
# 4050            California  15405843838
# 4051              Colorado   2742721576
# 4052           Connecticut   1385394654
# 4053              Delaware    433831127
# 4054  District of Columbia   1141626723
# 4055               Florida   8511101401
# 4056               Georgia   4948357555
# 4057                Hawaii    413389206
# 4058                 Idaho    690659433
# 4059              Illinois   7161797553
# 4060               Indiana   3279151830
# 4061                  Iowa   2875339160
# 4062                Kansas   1363485196
# 4063              Kentucky   2146866189
# 4064             Louisiana   2077358089
# 4065                 Maine    574159257
# 4066              Maryland   2311199243
# 4067         Massachusetts   3807861860
# ...

# %%
doe_2010 = pd.read_csv('../data/doe_2010.csv', encoding="cp1252") 
doe_2010 = doe_2010.reset_index(drop=True)

# %%
doe_2010 = doe_2010.iloc[3827:3878, 0:2]

# %%
doe_2010.columns = ["State or Other Area", "2010"]
doe_2010["2010"] = doe_2010["2010"].str.replace(",", "").astype(int)

# %%
doe_2010
# Out:
#        State or Other Area         2010
# 3827               Alabama   3061491531
# 3828                Alaska    427620917
# 3829               Arizona  10181765748
# 3830              Arkansas   1542976136
# 3831            California  18401548959
# 3832              Colorado   3383144560
# 3833           Connecticut   1685550603
# 3834              Delaware    529740270
# 3835  District of Columbia   1691927261
# 3836               Florida  10463075106
# 3837               Georgia   6605891175
# 3838                Hawaii    531380064
# 3839                 Idaho    835840129
# 3840              Illinois   9151542441
# 3841               Indiana   4430351597
# 3842                  Iowa   4200960740
# 3843                Kansas   1639412701
# 3844              Kentucky   2562570757
# 3845             Louisiana   2335545319
# 3846                 Maine    699844637
# 3847              Maryland   2751359220
# 3848         Massachusetts   4216387369
# ...

# %%
doe_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 3827 to 3877
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State or Other Area  51 non-null     object
#  1   2010                 51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 948.0+ bytes

# %%
doe_2011 = pd.read_csv('../data/doe_2011.csv', encoding="cp1252") 
doe_2011 = doe_2011.reset_index(drop=True)

# %%
doe_2011 = doe_2011.iloc[2748:2799, 0:2]

# %%
doe_2011.columns = ["State or Other Area", "2011"]
doe_2011["2011"] = doe_2011["2011"].str.replace(",", "").astype(int)

# %%
doe_2011
# Out:
#        State or Other Area         2011
# 2748               Alabama   2879238226
# 2749                Alaska    439835771
# 2750               Arizona   8998281669
# 2751              Arkansas   1460922257
# 2752            California  17284116871
# 2753              Colorado   3292972713
# 2754           Connecticut   1646164336
# 2755              Delaware    425976002
# 2756  District of Columbia   2026483134
# 2757               Florida  10371606989
# 2758               Georgia   5480540149
# 2759                Hawaii    524570628
# 2760                 Idaho    850625018
# 2761              Illinois   9240377997
# 2762               Indiana   4713456128
# 2763                  Iowa   4109414059
# 2764                Kansas   1573721244
# 2765              Kentucky   2507020977
# 2766             Louisiana   2270917150
# 2767                 Maine    697328857
# 2768              Maryland   2600882405
# 2769         Massachusetts   4134724107
# ...

# %%
doe_2012 = pd.read_csv('../data/doe_2012.csv', encoding="cp1252") 
doe_2012 = doe_2012.reset_index(drop=True)

# %%
doe_2012 = doe_2012.iloc[2709:2760, 0:2]

# %%
doe_2012.columns = ["State or Other Area", "2012"]
doe_2012["2012"] = doe_2012["2012"].str.replace(",", "").astype(int)

# %%
doe_2012
# Out:
#        State or Other Area         2012
# 2709               Alabama   2845395628
# 2710                Alaska    449975869
# 2711               Arizona   8049933183
# 2712              Arkansas   1423047882
# 2713            California  17137369513
# 2714              Colorado   3115240593
# 2715           Connecticut   1673317098
# 2716              Delaware    494678457
# 2717  District of Columbia   1825907540
# 2718               Florida  10068664972
# 2719               Georgia   5345573841
# 2720                Hawaii    520666928
# 2721                 Idaho    792902932
# 2722              Illinois   8390437386
# 2723               Indiana   4437703286
# 2724                  Iowa   3683386019
# 2725                Kansas   1557412486
# 2726              Kentucky   2440586319
# 2727             Louisiana   2220310520
# 2728                 Maine    679876882
# 2729              Maryland   2581620571
# 2730         Massachusetts   4057859325
# ...

# %%
doe_2013 = pd.read_csv('../data/doe_2013.csv', encoding="cp1252") 
doe_2013 = doe_2013.reset_index(drop=True)

# %%
doe_2013 = doe_2013.iloc[2785:2836, 0:2]

# %%
doe_2013.columns = ["State or Other Area", "2013"]
doe_2013["2013"] = doe_2013["2013"].str.replace(",", "").astype(int)

# %%
doe_2013
# Out:
#        State or Other Area         2013
# 2785               Alabama   2883319880
# 2786                Alaska    443908978
# 2787               Arizona   8189692878
# 2788              Arkansas   1412106992
# 2789            California  15768503224
# 2790              Colorado   3062212570
# 2791           Connecticut   1579567773
# 2792              Delaware    502047740
# 2793  District of Columbia   1861968103
# 2794               Florida  10071335584
# 2795               Georgia   5245788392
# 2796                Hawaii    509054102
# 2797                 Idaho    759674747
# 2798              Illinois   7839065368
# 2799               Indiana   4205383182
# 2800                  Iowa   3960865384
# 2801                Kansas   1513568780
# 2802              Kentucky   2438921454
# 2803             Louisiana   2216834661
# 2804                 Maine    657303871
# 2805              Maryland   2509739948
# 2806         Massachusetts   3827930586
# ...

# %%
doe_2014 = pd.read_csv('../data/doe_2014.csv', encoding="cp1252") 
doe_2014 = doe_2014.reset_index(drop=True)

# %%
doe_2014 = doe_2014.iloc[2401:2452, 0:2]

# %%
doe_2014.columns = ["State or Other Area", "2014"]
doe_2014["2014"] = doe_2014["2014"].str.replace(",", "").astype(int)

# %%
doe_2014
# Out:
#        State or Other Area         2014
# 2401               Alabama   2875991324
# 2402                Alaska    425276011
# 2403               Arizona   7477469186
# 2404              Arkansas   1405013760
# 2405            California  16816137363
# 2406              Colorado   2965284074
# 2407           Connecticut   1656657510
# 2408              Delaware    494499654
# 2409  District of Columbia   1781215703
# 2410               Florida   9992845894
# 2411               Georgia   5183160670
# 2412                Hawaii    494017469
# 2413                 Idaho    743821754
# 2414              Illinois   7649445916
# 2415               Indiana   4187494655
# 2416                  Iowa   2775868884
# 2417                Kansas   1611277229
# 2418              Kentucky   2346257238
# 2419             Louisiana   2240881517
# 2420                 Maine    705625906
# 2421              Maryland   2561599476
# 2422         Massachusetts   3890410364
# ...

# %%
doe_2015 = pd.read_csv('../data/doe_2015.csv', encoding="cp1252") 
doe_2015 = doe_2015.reset_index(drop=True)

# %%
doe_2015 = doe_2015.iloc[2326:2377, 0:2]

# %%
doe_2015.columns = ["State or Other Area", "2015"]
doe_2015["2015"] = doe_2015["2015"].str.replace(",", "").astype(int)

# %%
doe_2015
# Out:
#        State or Other Area         2015
# 2326               Alabama   2729781358
# 2327                Alaska    415238724
# 2328               Arizona   6241051368
# 2329              Arkansas   1334963163
# 2330            California  16727837255
# 2331              Colorado   2780371880
# 2332           Connecticut   1711664971
# 2333              Delaware    407209807
# 2334  District of Columbia   1667518726
# 2335               Florida   8838564032
# 2336               Georgia   5116975414
# 2337                Hawaii    451957657
# 2338                 Idaho    679872934
# 2339              Illinois   7469049674
# 2340               Indiana   3883891185
# 2341                  Iowa   2421686820
# 2342                Kansas   1499228798
# 2343              Kentucky   2157474471
# 2344             Louisiana   2176484426
# 2345                 Maine    657899841
# 2346              Maryland   2418090781
# 2347         Massachusetts   3951763992
# ...

# %%
doe_2016 = pd.read_csv('../data/doe_2016.csv', encoding="cp1252") 
doe_2016 = doe_2016.reset_index(drop=True)

# %%
doe_2016 = doe_2016.iloc[2401:2452, 0:4]

# %%
doe_2016
# Out:
#                 Unnamed: 0      Unnamed: 1      Unnamed: 2      Unnamed: 3
# 2401               Alabama   2,875,991,324   2,929,283,305   3,053,932,288
# 2402                Alaska     425,276,011     445,792,878     456,635,005
# 2403               Arizona   7,477,469,186   7,641,077,155   7,981,741,082
# 2404              Arkansas   1,405,013,760   1,419,774,860   1,464,872,811
# 2405            California  16,816,137,363  17,088,237,034  17,803,268,621
# 2406              Colorado   2,965,284,074   3,027,497,764   3,158,166,524
# 2407           Connecticut   1,656,657,510   1,689,404,269   1,751,745,595
# 2408              Delaware     494,499,654     502,781,642     521,825,598
# 2409  District of Columbia   1,781,215,703   1,832,837,904   1,923,544,302
# 2410               Florida   9,992,845,894  10,166,202,212  10,623,522,908
# 2411               Georgia   5,183,160,670   5,284,301,567   5,540,462,845
# ...

# %%
doe_2016 = doe_2016.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
doe_2016.columns = ["State or Other Area", "2016"]

# %%
doe_2016["2016"] = doe_2016["2016"].str.replace(",", "").astype(int)

# %%
doe_2016
# Out:
#        State or Other Area         2016
# 2401               Alabama   3053932288
# 2402                Alaska    456635005
# 2403               Arizona   7981741082
# 2404              Arkansas   1464872811
# 2405            California  17803268621
# 2406              Colorado   3158166524
# 2407           Connecticut   1751745595
# 2408              Delaware    521825598
# 2409  District of Columbia   1923544302
# 2410               Florida  10623522908
# 2411               Georgia   5540462845
# 2412                Hawaii    517621125
# 2413                 Idaho    782420357
# 2414              Illinois   8170869666
# 2415               Indiana   4449701053
# 2416                  Iowa   2975816717
# 2417                Kansas   1716917605
# 2418              Kentucky   2480188340
# 2419             Louisiana   2384286206
# 2420                 Maine    742226992
# 2421              Maryland   2718937482
# 2422         Massachusetts   4167295567
# ...

# %%
doe_2017 = pd.read_csv('../data/doe_2017.csv', encoding="cp1252") 
doe_2017 = doe_2017.reset_index(drop=True)

# %%
doe_2017 = doe_2017.iloc[2180:2231, 0:2]

# %%
doe_2017.columns = ["State or Other Area", "2017"]
doe_2017["2017"] = doe_2017["2017"].str.replace(",", "").astype(int)

# %%
doe_2017
# Out:
#        State or Other Area         2017
# 2180               Alabama   2831684185
# 2181                Alaska    403601683
# 2182               Arizona   5077168472
# 2183              Arkansas   1376380456
# 2184            California  17084027581
# 2185              Colorado   2765702017
# 2186           Connecticut   1773331356
# 2187              Delaware    459555434
# 2188  District of Columbia   1754283321
# 2189               Florida   8794744245
# 2190               Georgia   5109231256
# 2191                Hawaii    468240244
# 2192                 Idaho    689728418
# 2193              Illinois   7170081651
# 2194               Indiana   3319401466
# 2195                  Iowa   2230980596
# 2196                Kansas   1486510033
# 2197              Kentucky   2209055707
# 2198             Louisiana   2328611993
# 2199                 Maine    689862463
# 2200              Maryland   2511350458
# 2201         Massachusetts   4117827769
# ...

# %%
doe_2018 = pd.read_csv('../data/doe_2018.csv', dtype=str) 
doe_2018 = doe_2018.reset_index(drop=True)

# %%
doe_2018 = doe_2018.iloc[2150:2201, 0:2]

# %%
doe_2018.columns = ["State or Other Area", "2018"]
doe_2018["2018"] = doe_2018["2018"].str.replace(",", "").astype(int)

# %%
doe_2018
# Out:
#        State or Other Area         2018
# 2150               Alabama   2908765139
# 2151                Alaska    404828434
# 2152               Arizona   5080637675
# 2153              Arkansas   1401643324
# 2154            California  17516670303
# 2155              Colorado   2863430831
# 2156           Connecticut   1854947718
# 2157              Delaware    476592590
# 2158  District of Columbia   1853775976
# 2159               Florida   8940269535
# 2160               Georgia   5220842709
# 2161                Hawaii    457308984
# 2162                 Idaho    700226625
# 2163              Illinois   7196027858
# 2164               Indiana   3141193144
# 2165                  Iowa   2197721443
# 2166                Kansas   1497102093
# 2167              Kentucky   2270204083
# 2168             Louisiana   2489362542
# 2169                 Maine    700237650
# 2170              Maryland   2625009128
# 2171         Massachusetts   4227505004
# ...

# %%
doe_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 2150 to 2200
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   State or Other Area  51 non-null     object
#  1   2018                 51 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 948.0+ bytes

# %%
doe_2019 = pd.read_csv('../data/doe_2019.csv', dtype=str) 
doe_2019 = doe_2019.reset_index(drop=True)

# %%
doe_2019 = doe_2019.iloc[2116:2167, 0:2]

# %%
doe_2019.columns = ["State or Other Area", "2019"]
doe_2019["2019"] = doe_2019["2019"].str.replace(",", "").astype(int)

# %%
doe_2019
# Out:
#        State or Other Area         2019
# 2116               Alabama   2775338135
# 2117                Alaska    400523165
# 2118               Arizona   5143402498
# 2119              Arkansas   1350409184
# 2120            California  17212221075
# 2121              Colorado   2788049026
# 2122           Connecticut   1828889175
# 2123              Delaware    473804823
# 2124  District of Columbia   1838047295
# 2125               Florida   8753066640
# 2126               Georgia   5062246917
# 2127                Hawaii    449100414
# 2128                 Idaho    688908434
# 2129              Illinois   6657828557
# 2130               Indiana   3385141198
# 2131                  Iowa   1666660077
# 2132                Kansas   1439276872
# 2133              Kentucky   2208575378
# 2134             Louisiana   2513977136
# 2135                 Maine    672684725
# 2136              Maryland   2480450206
# 2137         Massachusetts   4052189459
# ...

# %%
doe_2020 = pd.read_csv('../data/doe_2020.csv', encoding="cp1252") 
doe_2020 = doe_2020.reset_index(drop=True)

# %%
doe_2020 = doe_2020.iloc[2039:2090, 0:2]

# %%
doe_2020.columns = ["State or Other Area", "2020"]
doe_2020["2020"] = doe_2020["2020"].str.replace(",", "").astype(int)

# %%
doe_2020
# Out:
#        State or Other Area         2020
# 2039               Alabama   2691718594
# 2040                Alaska    400083225
# 2041               Arizona   5385850713
# 2042              Arkansas   1344545069
# 2043            California  17154169150
# 2044              Colorado   2766594671
# 2045           Connecticut   1849505887
# 2046              Delaware    467652439
# 2047  District of Columbia   1851544286
# 2048               Florida   8730468668
# 2049               Georgia   4941432116
# 2050                Hawaii    430882558
# 2051                 Idaho    669357358
# 2052              Illinois   6440730096
# 2053               Indiana   3280054276
# 2054                  Iowa   1620396195
# 2055                Kansas   1414294642
# 2056              Kentucky   2248698102
# 2057             Louisiana   2518798316
# 2058                 Maine    655599146
# 2059              Maryland   2425352727
# 2060         Massachusetts   3910887919
# ...

# %%
doe_2021 = pd.read_csv('../data/doe_2021.csv', encoding="cp1252") 
doe_2021 = doe_2021.reset_index(drop=True)

# %%
doe_2021 = doe_2021.iloc[2125:2176, 0:2]
doe_2021.columns = ["State or Other Area", "2021"]

# %%
doe_2021["2021"] = doe_2021["2021"].str.replace(",", "").astype(int)

# %%
doe_2021
# Out:
#        State or Other Area         2021
# 2125               Alabama   2637187288
# 2126                Alaska    384569403
# 2127               Arizona   5423901031
# 2128              Arkansas   1320387586
# 2129            California  16960772229
# 2130              Colorado   2814490232
# 2131           Connecticut   1879316901
# 2132              Delaware    449853692
# 2133  District of Columbia   1722248421
# 2134               Florida   8833589122
# 2135               Georgia   4712308437
# 2136                Hawaii    439831763
# 2137                 Idaho    671464155
# 2138              Illinois   6723513048
# 2139               Indiana   3226664721
# 2140                  Iowa   1603492496
# 2141                Kansas   1383407700
# 2142              Kentucky   2248634277
# 2143             Louisiana   2594359483
# 2144                 Maine    641337830
# 2145              Maryland   2379171760
# 2146         Massachusetts   3883570968
# ...

# %%
doe_2023 = pd.read_csv('../data/doe_2023.csv', encoding="cp1252") 
doe_2023 = doe_2023.reset_index(drop=True)

# %%
doe_2023 = doe_2023.iloc[2045:2096, 0:2]
doe_2023.columns = ["State or Other Area", "2023"]

# %%
doe_2023["2023"] = doe_2023["2023"].str.replace(",", "").astype(int)

# %%
doe_2023
# Out:
#        State or Other Area         2023
# 2045               Alabama   2755576286
# 2046                Alaska    410535971
# 2047               Arizona   5996044985
# 2048              Arkansas   1412157643
# 2049            California  18335315420
# 2050              Colorado   2918425104
# 2051           Connecticut   2054428182
# 2052              Delaware    471572288
# 2053  District of Columbia   1792962576
# 2054               Florida   9652436459
# 2055               Georgia   5324728170
# 2056                Hawaii    486685411
# 2057                 Idaho    688106682
# 2058              Illinois   6818848717
# 2059               Indiana   3340895914
# 2060                  Iowa   1659976682
# 2061                Kansas   1385123550
# 2062              Kentucky   2425330125
# 2063             Louisiana   2774696659
# 2064                 Maine    672443269
# 2065              Maryland   2576700698
# 2066         Massachusetts   4098651225
# ...

# %%
doe_2024 = pd.read_csv('../data/doe_2024.csv', encoding="cp1252") 
doe_2024 = doe_2024.reset_index(drop=True)

# %%
doe_2024 = doe_2024.iloc[2177:2228, 0:4]

# %%
doe_2024 = doe_2024.drop(columns=['Unnamed: 1', 'Unnamed: 2'])
doe_2024.columns = ["State or Other Area", "2024"]

# %%
doe_2024["2024"] = doe_2024["2024"].str.replace(",", "").astype(int)

# %%
doe_2024
# Out:
#        State or Other Area         2024
# 2177               Alabama   2893796761
# 2178                Alaska    422320136
# 2179               Arizona   6061044941
# 2180              Arkansas   1475060578
# 2181            California  19213766520
# 2182              Colorado   3096422836
# 2183           Connecticut   2110311601
# 2184              Delaware    492229874
# 2185  District of Columbia   1848658976
# 2186               Florida  10172141276
# 2187               Georgia   5672476375
# 2188                Hawaii    520892850
# 2189                 Idaho    763049912
# 2190              Illinois   7210320126
# 2191               Indiana   3567259908
# 2192                  Iowa   1732317591
# 2193                Kansas   1501726955
# 2194              Kentucky   2537307370
# 2195             Louisiana   2954698636
# 2196                 Maine    702871058
# 2197              Maryland   2774400136
# 2198         Massachusetts   4280369005
# ...

# %%
doe_2000 = pd.read_csv('../data/doe_2000.csv', encoding="cp1252") 
doe_2000 = doe_2000.reset_index(drop=True)

# %%
doe_2000 = doe_2000.iloc[3410:3461, 0:2]
doe_2000.columns = ["State or Other Area", "2000"]

# %%
doe_2000["2000"] = doe_2000["2000"].str.replace(",", "").astype(int)

# %%
doe_2000
# Out:
#        State or Other Area        2000
# 3410               Alabama   557767814
# 3411                Alaska   177881580
# 3412               Arizona   667976456
# 3413              Arkansas   328403457
# 3414            California  3792096590
# 3415              Colorado   370882855
# 3416           Connecticut   288895735
# 3417              Delaware    85735787
# 3418  District of Columbia   115040586
# 3419               Florida  1590311741
# 3420               Georgia   822536045
# 3421                Hawaii   132643273
# 3422                 Idaho   150011363
# 3423              Illinois  1272164392
# 3424               Indiana   588909058
# 3425                  Iowa   305590676
# 3426                Kansas   296011073
# 3427              Kentucky   501796366
# 3428             Louisiana   643637545
# 3429                 Maine   154133835
# 3430              Maryland   461461303
# 3431         Massachusetts   662761571
# 3432              Michigan  1105793304
# ...

# %%
dfs = [doe_2000, doe_2001_2008, doe_2009, doe_2010, doe_2011, doe_2012, doe_2013, doe_2014, doe_2015, doe_2016, doe_2017, doe_2018, doe_2019, doe_2020, doe_2021, doe_2022, doe_2023, doe_2024]

ed_merged_wide = pd.concat(
    [df.set_index("State or Other Area") for df in dfs], 
    axis=1
).reset_index()

# %%
ed_merged_wide
# Out:
#      State or Other Area        2000        2001        2002        2003  \
# 0                Alabama   557767814  1205096441  1387975241  1584581070
# 1                 Alaska   177881580   227988480   260180178   280079667
# 2                Arizona   667976456  1990909460  2520137525  3103945066
# 3               Arkansas   328403457   618218324   733650835   829601733
# 4             California  3792096590  7895473833  9092121808  9928105199
# 5               Colorado   370882855  1061188114  1238777106  1416997560
# 6            Connecticut   288895735   703315579   825970250   908683240
# 7               Delaware    85735787   187754734   216149404   226632147
# 8   District of Columbia   115040586   596359049   663632391   747391195
# 9                Florida  1590311741  3622745422  4124966740  4631097940
# 10               Georgia   822536045  1973334617  2313606367  2618655949
# 11                Hawaii   132643273   229367192   271216945   296507436
# ...

# %%
ed_merged_long = ed_merged_wide.melt(
    id_vars="State or Other Area",   # keep this column as is
    var_name="Year",                 # new column name for former wide column headers
    value_name="Value"               # new column name for the numbers
)

# %%
ed_merged_long
# Out:
#      State or Other Area  Year       Value
# 0                Alabama  2000   557767814
# 1                 Alaska  2000   177881580
# 2                Arizona  2000   667976456
# 3               Arkansas  2000   328403457
# 4             California  2000  3792096590
# ...                  ...   ...         ...
# 1270            Virginia  2024  4945926328
# 1271          Washington  2024  2629297055
# 1272       West Virginia  2024  1171148805
# 1273           Wisconsin  2024  2505089591
# 1274             Wyoming  2024   276703849
#
# [1275 rows x 3 columns]

# %%
ed_merged_long.rename(columns={"State or Other Area": "State"}, inplace=True)

# %%
ed_merged_long
# Out:
#               State  Year       Value
# 0           Alabama  2000   557767814
# 1            Alaska  2000   177881580
# 2           Arizona  2000   667976456
# 3          Arkansas  2000   328403457
# 4        California  2000  3792096590
# ...             ...   ...         ...
# 1270       Virginia  2024  4945926328
# 1271     Washington  2024  2629297055
# 1272  West Virginia  2024  1171148805
# 1273      Wisconsin  2024  2505089591
# 1274        Wyoming  2024   276703849
#
# [1275 rows x 3 columns]

# %%
ed_merged_long["Year"] = ed_merged_long["Year"].astype(int)

inflation_factors = {
    2000: 1.83, 2001: 1.76, 2002: 1.74, 2003: 1.70, 
    2004: 1.67, 2005: 1.62, 2006: 1.56, 2007: 1.52,
    2008: 1.46, 2009: 1.46, 2010: 1.42, 2011: 1.40,
    2012: 1.36, 2013: 1.34, 2014: 1.32, 2015: 1.32,
    2016: 1.30, 2017: 1.27, 2018: 1.24, 2019: 1.23,
    2020: 1.20, 2021: 1.18, 2022: 1.10, 2023: 1.03,
    2024: 1.00
}

ed_merged_long["Inflation_Factor"] = ed_merged_long["Year"].map(inflation_factors)

ed_merged_long["Value_adj"] = ed_merged_long["Value"] * ed_merged_long["Inflation_Factor"]

# %%
ed_merged_long.head(50)
# Out:
#                    State  Year       Value  Inflation_Factor     Value_adj
# 0                Alabama  2000   557767814              1.83  1.020715e+09
# 1                 Alaska  2000   177881580              1.83  3.255233e+08
# 2                Arizona  2000   667976456              1.83  1.222397e+09
# 3               Arkansas  2000   328403457              1.83  6.009783e+08
# 4             California  2000  3792096590              1.83  6.939537e+09
# 5               Colorado  2000   370882855              1.83  6.787156e+08
# 6            Connecticut  2000   288895735              1.83  5.286792e+08
# 7               Delaware  2000    85735787              1.83  1.568965e+08
# 8   District of Columbia  2000   115040586              1.83  2.105243e+08
# 9                Florida  2000  1590311741              1.83  2.910270e+09
# 10               Georgia  2000   822536045              1.83  1.505241e+09
# ...

# %%
ed_merged_long.to_csv("../data/ed_merged_long.csv", index=False)

# %%
ed_merged_filtered = ed_merged_long[
    (ed_merged_long["Year"] >= 2000) & 
    (ed_merged_long["Year"] <= 2021)
]


state_avg = (
    ed_merged_filtered.groupby("State")["Value_adj"]
    .mean()
    .round(1)
    .reset_index()
)


state_avg_sorted = state_avg.sort_values(by="Value_adj", ascending=False).reset_index(drop=True)

# %%
state_avg_sorted
# Out:
#                    State     Value_adj
# 0             California  1.972517e+10
# 1               New York  1.357465e+10
# 2                  Texas  1.317121e+10
# 3                Florida  1.055641e+10
# 4           Pennsylvania  8.839659e+09
# 5               Illinois  8.758405e+09
# 6                Arizona  8.017639e+09
# 7                   Ohio  7.164295e+09
# 8               Michigan  6.429868e+09
# 9                Georgia  5.919851e+09
# 10              Virginia  4.840612e+09
# 11        North Carolina  4.764693e+09
# 12         Massachusetts  4.657452e+09
# 13             Minnesota  4.503099e+09
# 14               Indiana  4.304878e+09
# 15              Missouri  4.028526e+09
# 16            New Jersey  3.897749e+09
# 17             Tennessee  3.568717e+09
# 18              Colorado  3.304514e+09
# 19               Alabama  3.181627e+09
# 20                  Iowa  3.076580e+09
# 21             Wisconsin  3.009440e+09
# 22            Washington  2.995498e+09
# ...

# %%
state_avg_sorted.to_csv("../data/avg_ed_merged_by_state.csv", index=False)
